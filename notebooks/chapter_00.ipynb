# %% [markdown]
# ## Chapter 0: Setup
#
# <a target="_blank" href="https://colab.research.google.com/github/wandb/eval-course/blob/main/notebooks/chapter_00.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <!--- @wandbcode{eval-course-00} -->
#
# Let's install the required packages and check our setup for this course.
#
# ### 🎉 Free Google AI Studio Access
#
# Before you run this colab notebook, you'll need access to Google's Generative AI models. Here's how to get started:
#
# 1. Visit [Google AI Studio](https://makersuite.google.com/app/home) and sign in with your Google account
# 2. Get your API key from the "Get API key" section in Google AI Studio
#
# Alternatively, if you already have a Google AI Studio API key, feel free to proceed. :)

# %%
# !pip install -qq weave google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 98.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 2.7.1 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.

# %% [markdown]
# ## 1. Setup Weave
#
#
# The code cell below will prompt you to put in a W&B API key. You can get your API key by heading over to https://wandb.ai/authorize.

# %%
# import weave
import weave

# initialize weave client
weave_client = weave.init("eval_course_ch0")
# Out:
# weave: Please login to Weights & Biases (https://wandb.ai) to continue...
# weave: Logging into Weights & Biases
# weave: You can find your API key in your browser here: https://wandb.ai/authorize?ref=weave
# weave: Paste an API key from your profile and hit enter:
# Enter your Weights & Biases API key: ··········
# weave: W&B API key is configured. Use `wandb login --relogin` to force relogin
# weave: Logged in as Weights & Biases user: thesisdfki.
# weave: View Weave data at https://wandb.ai/thesisdfki-dfki/eval_course_ch0/weave

# %% [markdown]
# ## 2. Setup Google AI Studio
#
# The code cell below will prompt you to put in a Google AI Studio API key.

# %%
import getpass

import google.generativeai as genai

genai.configure(api_key=getpass.getpass("Please enter your Google AI Studio API key"))
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Please enter your Google AI Studio API key··········

# %% [markdown]
# ## A simple-turn chat with Google AI Studio's gemini-2.0-flash-exp

# %%
model = genai.GenerativeModel("models/gemini-flash-latest")
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3647.18ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 18714.21ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 4963.43ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 15347.34ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 11115.91ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3955.40ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 4966.30ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 8428.81ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6914.39ms
# At its core, **Artificial Intelligence (AI) does not "think" the way a human does.** It doesn’t have feelings, consciousness, or common sense.
#
# Instead, modern AI works through **advanced pattern recognition using mathematics, data, and statistics.**
#
# To understand how it works, it helps to compare it to traditional computer programming, look at the steps required to build it, and see how modern systems (like ChatGPT) operate.
#
# ---
#
# ### 1. Traditional Coding vs. AI
# * **Traditional Programming:** A human writes strict rules.
#   * *Example:* "IF an image contains two pointy triangles at the top and whiskers in the middle, THEN label it a cat." (If a cat is facing away, the program fails).
# * **Artificial Intelligence (Machine Learning):** Instead of writing the rules, humans feed the computer thousands of examples and let it figure out the rules on its own.
#   * *Example:* "Here are 10,000 photos of cats and 10,000 photos of not-cats. Figure out what makes a cat a cat."
#
# ---
#
# ### 2. The 4 Steps of How AI Learns
#
# Most AI today uses a method called **Machine Learning**. Here is the step-by-step process of how an AI system is created:
#
# #### Step 1: Data Collection (The Fuel)
# AI cannot learn without data. This can be text, images, video, sensor readings, or audio.
# * *Rule:* The better and larger the dataset, the smarter the AI will be.
#
# #### Step 2: Training (The Practice)
# The AI is given an **algorithm** (a set of mathematical equations). During training, the AI looks at the data and makes a guess:
# 1. It looks at a picture of a cat and guesses: *"I think this is a dog (80% confidence)."*
# 2. The system checks the answer key: *"Wrong, it's a cat."*
# 3. The algorithm **adjusts its internal math** slightly so it makes a better guess next time.
# 4. It repeats this process millions—or billions—of times until its guesses are highly accurate.
#
# #### Step 3: Evaluation (The Final Exam)
# The AI is tested with *new* data it has never seen before to ensure it actually learned the underlying patterns rather than just memorizing the answers (a problem known as "overfitting").
#
# #### Step 4: Inference (Putting it to Work)
# Once trained, the AI is frozen and deployed into an app. When you upload a photo to Google Photos or ask Siri a question, the AI uses what it learned to give you an answer in seconds.
#
# ---
#
# ### 3. Deep Learning: Mimicking the Brain
# The most powerful form of AI today is called **Deep Learning**, which uses **Artificial Neural Networks**. These are inspired by the human brain.
#
# A neural network consists of layers of mathematical "nodes" (artificial neurons):
# * **Input Layer:** Takes in raw data (e.g., individual pixels of an image).
# * **Hidden Layers:** These process the data at increasing levels of complexity.
#   * Layer 1 might detect simple edges and lines.
#   * Layer 2 combines edges to detect shapes (circles, triangles).
#   * Layer 3 combines shapes to detect features (eyes, noses, wheels).
# * **Output Layer:** Gives the final result (e.g., "99% chance this is a bicycle").
#
# ---
#
# ### 4. How Generative AI (like ChatGPT) Works
# Recent tools like ChatGPT, Claude, and Midjourney are called **Generative AI**.
#
# Text-based systems are known as **Large Language Models (LLMs)**. They do not "know" facts; they are essentially **supercharged autocomplete systems**:
# 1. They were trained on a massive portion of the public internet (books, articles, websites).
# 2. Through this, they learned the statistical likelihood of which words follow other words.
# 3. When you ask ChatGPT a question, it calculates: *"Given this prompt, what is mathematically the best sequence of words to write next?"*
#
# Because these models have ingested so much human knowledge, their statistical predictions sound remarkably natural, logical, and human-like.
#
# ---
#
# ### Summary Analogy
# Think of AI like a **child learning to play basketball**:
# * At first, they don't know how much strength to use. They shoot, miss, and see the result.
# * Their brain adjusts the muscles slightly.
# * After 10,000 practice shots, their brain has built an internal "model" of how to shoot accurately from anywhere on the court.
#
# AI does the exact same thing—except instead of muscle memory, it uses **math and data**.

# %%
for m in genai.list_models():
  if "generateContent" in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-omni-1.1-flash
# models/gemini-3.5-transcribe
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/gemini-3.8-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/lyria-3.5
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/antigravity-preview-09-2026
# models/antigravity-preview-latest
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %% [markdown]
# Let's head over to the weave URL to check out the generated response.
